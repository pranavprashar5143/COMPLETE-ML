# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('economy.csv')

# %%
df
# Out:
#               date   airline ch_code  num_code dep_time     from time_taken  \
# 0       11-02-2022  SpiceJet      SG      8709    18:55    Delhi    02h 10m
# 1       11-02-2022  SpiceJet      SG      8157    06:20    Delhi    02h 20m
# 2       11-02-2022   AirAsia      I5       764    04:25    Delhi    02h 10m
# 3       11-02-2022   Vistara      UK       995    10:20    Delhi    02h 15m
# 4       11-02-2022   Vistara      UK       963    08:50    Delhi    02h 20m
# ...            ...       ...     ...       ...      ...      ...        ...
# 206769  31-03-2022   Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022   Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022   Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022   Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022   Vistara      UK       824    20:30  Chennai    24h 25m
#
# ...

# %%
df.tail()
# Out:
#               date  airline ch_code  num_code dep_time     from time_taken  \
# 206769  31-03-2022  Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022  Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022  Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022  Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022  Vistara      UK       824    20:30  Chennai    24h 25m
#
#                                                      stop arr_time         to  \
# 206769  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 206770  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 206771  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    09:05  Hyderabad
# 206772  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    09:05  Hyderabad
# 206773  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
#
#         price
# 206769  7,697
# 206770  7,709
# ...

# %%
#get the basic info of daata 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206774 entries, 0 to 206773
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        206774 non-null  object
#  1   airline     206774 non-null  object
#  2   ch_code     206774 non-null  object
#  3   num_code    206774 non-null  int64
#  4   dep_time    206774 non-null  object
#  5   from        206774 non-null  object
#  6   time_taken  206774 non-null  object
#  7   stop        206774 non-null  object
#  8   arr_time    206774 non-null  object
#  9   to          206774 non-null  object
#  10  price       206774 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 17.4+ MB

# %%
df.head()
# Out:
#          date   airline ch_code  num_code dep_time   from time_taken  \
# 0  11-02-2022  SpiceJet      SG      8709    18:55  Delhi    02h 10m
# 1  11-02-2022  SpiceJet      SG      8157    06:20  Delhi    02h 20m
# 2  11-02-2022   AirAsia      I5       764    04:25  Delhi    02h 10m
# 3  11-02-2022   Vistara      UK       995    10:20  Delhi    02h 15m
# 4  11-02-2022   Vistara      UK       963    08:50  Delhi    02h 20m
#
#         stop arr_time      to  price
# 0  non-stop     21:05  Mumbai  5,953
# 1  non-stop     08:40  Mumbai  5,953
# 2  non-stop     06:35  Mumbai  5,956
# 3  non-stop     12:35  Mumbai  5,955
# 4  non-stop     11:10  Mumbai  5,955

# %%
#feature engineering
df['date_of_journey']=df['date'].str.split('-').str[0]
df['month_of_journey']=df['date'].str.split('-').str[1]
df['year_of_journey']=df['date'].str.split('-').str[2]

# %%
df.head()
# Out:
#          date   airline ch_code  num_code dep_time   from time_taken  \
# 0  11-02-2022  SpiceJet      SG      8709    18:55  Delhi    02h 10m
# 1  11-02-2022  SpiceJet      SG      8157    06:20  Delhi    02h 20m
# 2  11-02-2022   AirAsia      I5       764    04:25  Delhi    02h 10m
# 3  11-02-2022   Vistara      UK       995    10:20  Delhi    02h 15m
# 4  11-02-2022   Vistara      UK       963    08:50  Delhi    02h 20m
#
#         stop arr_time      to  price date of journey date_of_journey  \
# 0  non-stop     21:05  Mumbai  5,953              11              11
# 1  non-stop     08:40  Mumbai  5,953              11              11
# 2  non-stop     06:35  Mumbai  5,956              11              11
# 3  non-stop     12:35  Mumbai  5,955              11              11
# 4  non-stop     11:10  Mumbai  5,955              11              11
#
#   month_of_journey year_of_journey
# 0               02            2022
# 1               02            2022
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206774 entries, 0 to 206773
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              206774 non-null  object
#  1   airline           206774 non-null  object
#  2   ch_code           206774 non-null  object
#  3   num_code          206774 non-null  int64
#  4   dep_time          206774 non-null  object
#  5   from              206774 non-null  object
#  6   time_taken        206774 non-null  object
#  7   stop              206774 non-null  object
#  8   arr_time          206774 non-null  object
#  9   to                206774 non-null  object
#  10  price             206774 non-null  object
#  11  date of journey   206774 non-null  object
#  12  date_of_journey   206774 non-null  object
#  13  month_of_journey  206774 non-null  object
#  14  year_of_journey   206774 non-null  object
# dtypes: int64(1), object(14)
# ...

# %%
df['date_of_journey']=df['date_of_journey'].astype(int)
df['month_of_journey']=df['month_of_journey'].astype(int)
df['year_of_journey']=df['year_of_journey'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206774 entries, 0 to 206773
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           206774 non-null  object
#  1   ch_code           206774 non-null  object
#  2   num_code          206774 non-null  int64
#  3   dep_time          206774 non-null  object
#  4   from              206774 non-null  object
#  5   time_taken        206774 non-null  object
#  6   stop              206774 non-null  object
#  7   arr_time          0 non-null       float64
#  8   to                206774 non-null  object
#  9   price             206774 non-null  object
#  10  date of journey   206774 non-null  object
#  11  date_of_journey   206774 non-null  int64
#  12  month_of_journey  206774 non-null  int64
#  13  year_of_journey   206774 non-null  int64
# dtypes: float64(1), int64(4), object(9)
# memory usage: 22.1+ MB

# %%
#df.drop('date',axis=1,inplace=True)

# %%
df.head(2)
# Out:
#     airline ch_code  num_code dep_time   from time_taken       stop arr_time  \
# 0  SpiceJet      SG      8709    18:55  Delhi    02h 10m  non-stop     21:05
# 1  SpiceJet      SG      8157    06:20  Delhi    02h 20m  non-stop     08:40
#
#        to  price date of journey  date_of_journey  month_of_journey  \
# 0  Mumbai  5,953              11               11                 2
# 1  Mumbai  5,953              11               11                 2
#
#    year_of_journey
# 0             2022
# 1             2022

# %%
df['arr_time'] = df['arr_time'].astype('object')   # Extracts the hour part (e.g., "21" from "21:45")
# Extracts the minute part (e.g., "45" from "21:45")
df['arr_hr']=df['arr_time'].str.split(':').str[0]
df['arr_min']=df['arr_time'].str.split(':').str[1]

# %%
df.head(2)
# Out:
#     airline ch_code  num_code dep_time   from time_taken       stop arr_time  \
# 0  SpiceJet      SG      8709    18:55  Delhi    02h 10m  non-stop       NaN
# 1  SpiceJet      SG      8157    06:20  Delhi    02h 20m  non-stop       NaN
#
#        to  price date of journey  date_of_journey  month_of_journey  \
# 0  Mumbai  5,953              11               11                 2
# 1  Mumbai  5,953              11               11                 2
#
#    year_of_journey arr_hr arr_min
# 0             2022    NaN     NaN
# 1             2022    NaN     NaN
